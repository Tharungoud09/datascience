# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
data1 = pd.read_csv("NewspaperData.csv")
data1
# Out:
#                          Newspaper     daily    sunday
# 0                    Baltimore Sun   391.952   488.506
# 1                     Boston Globe   516.981   798.298
# 2                    Boston Herald   355.628   235.084
# 3               Charlotte Observer   238.555   299.451
# 4                Chicago Sun Times   537.780   559.093
# 5                  Chicago Tribune   733.775  1133.249
# 6              Cincinnati Enquirer   198.832   348.744
# 7                      Denver Post   252.624   417.779
# 8              Des Moines Register   206.204   344.522
# 9                 Hartford Courant   231.177   323.084
# 10               Houston Chronicle   449.755   620.752
# 11                Kansas City Star   288.571   423.305
# 12         Los Angeles Daily  News   185.736   202.614
# 13               Los Angeles Times  1164.388  1531.527
# 14                    Miami Herald   444.581   553.479
# 15        Minneapolis Star Tribune   412.871   685.975
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Newspaper  34 non-null     object
#  1   daily      34 non-null     float64
#  2   sunday     34 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 948.0+ bytes

# %%
data1.describe()
# Out:
#              daily       sunday
# count    34.000000    34.000000
# mean    430.962471   591.202412
# std     269.211470   376.418051
# min     133.239000   202.614000
# 25%     233.021500   327.769500
# 50%     355.235500   436.712500
# 75%     516.616500   699.735250
# max    1209.225000  1762.015000

# %%
plt.figure(figsize=(6,2))
boxplot_data = plt.boxplot(data1["daily"], vert=False)
[item.get_xdata() for item in boxplot_data['fliers']]
# Out:
# [array([1164.388, 1209.225])]

# %%
sns.histplot(data1["daily"], kde=True, ax=axes[0], color='purple', bins=30)
axes[0].set_title("Histogram with KDE")
axes[0].set_xlabel("Ozone Levels")
axes[0].set_ylabel("Frequency")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.histplot(data1["daily"], kde=True, ax=axes[0], color='purple', bins=30)
#       2 axes[0].set_title("Histogram with KDE")
#       3 axes[0].set_xlabel("Ozone Levels")
#
# NameError: name 'axes' is not defined

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios': [1, 3]})
#                        rows,colums 

#plot the boxplot in the first (top) subplot
sns.boxplot(data=data1["daily"], ax=axes[0], color = 'skyblue', width=0.5, orient = 'h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("daily paper sales")
#  axes 0 -> first row
# plot the histogram with kde curve in the second (bottom) subplot

sns.histplot(data1["daily"], kde=True, ax=axes[1], color='purple', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("daily paper sales")
axes[1].set_ylabel("Frequency")

#adjust layout for better spaces
plt.tight_layout()

# show the plot
plt.show()

# %%
plt.scatter(data1["daily"],data1["sunday"])
plt.show()

# %%
data1["daily"].corr(data1["sunday"])
# Out:
# 0.9581543140785462

# %% [markdown]
# #### observation
# - very strong co-relation is found

# %%
import statsmodels.formula.api as smf
model = smf.ols("sunday~daily",data = data1).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 sunday   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     358.5
# Date:                Mon, 03 Feb 2025   Prob (F-statistic):           6.02e-19
# Time:                        09:33:01   Log-Likelihood:                -206.85
# No. Observations:                  34   AIC:                             417.7
# Df Residuals:                      32   BIC:                             420.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.8356     35.804      0.386      0.702     -59.095      86.766
# ...

# %%
x = data1["daily"].values
y = data1["sunday"].values
plt.scatter(x, y, color = "m", marker = "o", s = 30)
b0 = 13.84
b1 = 1.33
y_hat = b0 + b1*x
plt.plot(x, y_hat, color = "g")

plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
data1.corr(numeric_only=True)
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %%
import statsmodels.formula.api as smf
model1 = smf.ols("sunday~daily",data = data1).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 sunday   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     358.5
# Date:                Mon, 03 Feb 2025   Prob (F-statistic):           6.02e-19
# Time:                        10:01:05   Log-Likelihood:                -206.85
# No. Observations:                  34   AIC:                             417.7
# Df Residuals:                      32   BIC:                             420.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.8356     35.804      0.386      0.702     -59.095      86.766
# ...

# %% [markdown]
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The probabilty(p-value) for intercept (beta_0) is 0.707 > 0.05
# Therefore the intercept coefficient may not be that much significant in prediction
# However the p-value for "daily" (beta_1) is 0.00 < 0.05
# Therefore the beta_1 cofficient is highly significant and is contributiant to predicition.

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 sunday   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     358.5
# Date:                Mon, 03 Feb 2025   Prob (F-statistic):           6.02e-19
# Time:                        10:02:58   Log-Likelihood:                -206.85
# No. Observations:                  34   AIC:                             417.7
# Df Residuals:                      32   BIC:                             420.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.8356     35.804      0.386      0.702     -59.095      86.766
# ...

# %%
model1.params
# Out:
# Intercept    13.835630
# daily         1.339715
# dtype: float64

# %%
print(f'model t-values:\n{model1.tvalues}\n-----------\nmodel p-values: \n{model1.pvalues}')
# Out:
# model t-values:
# Intercept     0.386427
# daily        18.934840
# dtype: float64
# -----------
# model p-values:
# Intercept    7.017382e-01
# daily        6.016802e-19
# dtype: float64

# %%
(model1.rsquared,model1.rsquared_adj)
# Out:
# (0.9180596895873295, 0.9154990548869336)

# %% [markdown]
# # predict for new data

# %%
newdata=pd.Series([200,300,1500])

# %%
data_pred=pd.DataFrame(newdata,columns=['daily'])
data_pred
# Out:
#    daily
# 0    200
# 1    300
# 2   1500

# %%
model1.predict(data_pred)
# Out:
# 0     281.778581
# 1     415.750057
# 2    2023.407766
# dtype: float64

# %%
pred = model1.predict(data1["daily"])
pred
# Out:
# 0      538.939509
# 1      706.442705
# 2      490.275710
# 3      333.431284
# 4      734.307432
# 5      996.884826
# 6      280.213795
# 7      352.279731
# 8      290.090172
# 9      323.546868
# 10     616.379041
# 11     400.438457
# 12     262.668890
# 13    1573.783417
# 14     609.447357
# 15     566.965002
# 16     378.613164
# 17    1061.219269
# 18    1633.852208
# 19    1119.786239
# 20     313.594128
# 21     489.224034
# 22     704.489401
# 23     309.195844
# 24     466.219792
# 25     277.920203
# 26     192.337885
# 27     514.901007
# 28     380.708478
# 29     777.960698
# 30     538.047259
# 31     284.270451
# 32     444.722729
# 33    1137.725020
# dtype: float64

# %%
# add predicted valuesa as a column in data1
data1["Y_hat"] = pred
data1
# Out:
#                          Newspaper     daily    sunday        Y_hat
# 0                    Baltimore Sun   391.952   488.506   538.939509
# 1                     Boston Globe   516.981   798.298   706.442705
# 2                    Boston Herald   355.628   235.084   490.275710
# 3               Charlotte Observer   238.555   299.451   333.431284
# 4                Chicago Sun Times   537.780   559.093   734.307432
# 5                  Chicago Tribune   733.775  1133.249   996.884826
# 6              Cincinnati Enquirer   198.832   348.744   280.213795
# 7                      Denver Post   252.624   417.779   352.279731
# 8              Des Moines Register   206.204   344.522   290.090172
# 9                 Hartford Courant   231.177   323.084   323.546868
# 10               Houston Chronicle   449.755   620.752   616.379041
# 11                Kansas City Star   288.571   423.305   400.438457
# 12         Los Angeles Daily  News   185.736   202.614   262.668890
# ...

# %%
#compute the erroe values (residuals) and add as another column
data1["residuals"] = data1["sunday"] - data1["Y_hat"]
data1
# Out:
#                          Newspaper     daily    sunday        Y_hat  \
# 0                    Baltimore Sun   391.952   488.506   538.939509
# 1                     Boston Globe   516.981   798.298   706.442705
# 2                    Boston Herald   355.628   235.084   490.275710
# 3               Charlotte Observer   238.555   299.451   333.431284
# 4                Chicago Sun Times   537.780   559.093   734.307432
# 5                  Chicago Tribune   733.775  1133.249   996.884826
# 6              Cincinnati Enquirer   198.832   348.744   280.213795
# 7                      Denver Post   252.624   417.779   352.279731
# 8              Des Moines Register   206.204   344.522   290.090172
# 9                 Hartford Courant   231.177   323.084   323.546868
# 10               Houston Chronicle   449.755   620.752   616.379041
# 11                Kansas City Star   288.571   423.305   400.438457
# 12         Los Angeles Daily  News   185.736   202.614   262.668890
# ...

# %%
# compute Mean squared error for the model

mse = np.mean((data1["daily"]-data1["Y_hat"])**2)
rmse = np.sqrt(mse)
print("MSE: ",mse)
print("RMSE: ",rmse)
# Out:
# MSE:  33794.87469205249
# RMSE:  183.833823580027

# %%
plt.scatter(data1["Y_hat"], data1["residuals"])

# %% [markdown]
# #### observation
# the residuals are randomly scattered
# hence the assumption of homoscedasticity is satisfied(constant variannce in residuals)

# %%
import statsmodels.api as sm
sm.qqplot(data1["residuals"], line='45', fit=True)
plt.show()
